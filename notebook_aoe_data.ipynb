# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/aoe_data.csv')

# %%
df.head()
# Out:
#             match_id     map map_size  duration             dataset  \
# 50453403    50453403  Arabia     Tiny      3445  Definitive Edition
# 118982970  118982970   Arena     Tiny      2932  Definitive Edition
# 57185801    57185801   Arena     Tiny      2573  Definitive Edition
# 64335748    64335748  Arabia     Tiny       851  Definitive Edition
# 116883036  116883036  Arabia     Tiny      4737  Definitive Edition
#
#           difficulty     elo   p1_civ   p2_civ  p1_xpos  p2_xpos  p1_ypos  \
# 50453403     Hardest  1104.0  Vikings   Mayans     92.0     24.0     37.0
# 118982970    Hardest   884.5  Britons    Goths     70.0     82.0     16.0
# 57185801     Hardest   905.5  Chinese  Malians     69.0     61.0     16.0
# 64335748     Hardest  1080.0   Mayans  Magyars     25.0     98.0     80.0
# 116883036    Hardest  1050.0  Berbers    Slavs     83.0     30.0     28.0
#
#            p2_ypos  winner
# 50453403      78.0       0
# 118982970     98.0       0
# 57185801     104.0       0
# 64335748      68.0       1
# 116883036     85.0       1

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#     match_id     map map_size  duration             dataset difficulty  \
# 0   50453403  Arabia     Tiny      3445  Definitive Edition    Hardest
# 1  118982970   Arena     Tiny      2932  Definitive Edition    Hardest
# 2   57185801   Arena     Tiny      2573  Definitive Edition    Hardest
# 3   64335748  Arabia     Tiny       851  Definitive Edition    Hardest
# 4  116883036  Arabia     Tiny      4737  Definitive Edition    Hardest
#
#       elo   p1_civ   p2_civ  p1_xpos  p2_xpos  p1_ypos  p2_ypos  winner
# 0  1104.0  Vikings   Mayans     92.0     24.0     37.0     78.0       0
# 1   884.5  Britons    Goths     70.0     82.0     16.0     98.0       0
# 2   905.5  Chinese  Malians     69.0     61.0     16.0    104.0       0
# 3  1080.0   Mayans  Magyars     25.0     98.0     80.0     68.0       1
# 4  1050.0  Berbers    Slavs     83.0     30.0     28.0     85.0       1

# %%
df.dtypes
# Out:
# match_id        int64
# map            object
# map_size       object
# duration        int64
# dataset        object
# difficulty     object
# elo           float64
# p1_civ         object
# p2_civ         object
# p1_xpos       float64
# p2_xpos       float64
# p1_ypos       float64
# p2_ypos       float64
# winner          int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# match_id          0
# map               0
# map_size          0
# duration          0
# dataset           0
# difficulty        0
# elo               0
# p1_civ            0
# p2_civ            0
# p1_xpos       10596
# p2_xpos       10596
# p1_ypos       10596
# p2_ypos       10596
# winner            0
# dtype: int64

# %%
df[df.p1_xpos.isna()]
# Out:
#          match_id               map map_size  duration             dataset  \
# 7        65663102            Steppe     Tiny      2583  Definitive Edition
# 14       67097038  African Clearing     Tiny      1691  Definitive Edition
# 16      117048242             Nomad     Tiny      2999  Definitive Edition
# 28       65546519            Steppe     Tiny      2772  Definitive Edition
# 111     117288864  African Clearing     Tiny      2221  Definitive Edition
# ...           ...               ...      ...       ...                 ...
# 224537   64673962            Steppe     Tiny      2090  Definitive Edition
# 224548  113475755             Nomad     Tiny      1542  Definitive Edition
# 224549  117515774  African Clearing     Tiny      2875  Definitive Edition
# 224588  141124431  African Clearing     Tiny      2626  Definitive Edition
# 224595  114000000             Nomad     Tiny      3208  Definitive Edition
#
#        difficulty     elo      p1_civ       p2_civ  p1_xpos  p2_xpos  p1_ypos  \
# 7         Hardest   994.5      Cumans        Celts      NaN      NaN      NaN
# 14        Hardest  1555.0     Magyars       Mayans      NaN      NaN      NaN
# 16        Hardest  1053.5      Tatars      Koreans      NaN      NaN      NaN
# 28        Hardest  1048.5       Goths      Magyars      NaN      NaN      NaN
# 111       Hardest  1261.0  Vietnamese      Spanish      NaN      NaN      NaN
# ...           ...     ...         ...          ...      ...      ...      ...
# 224537    Hardest  1225.5      Franks       Tatars      NaN      NaN      NaN
# 224548    Hardest  1145.0  Bulgarians       Mayans      NaN      NaN      NaN
# 224549    Hardest  1025.0  Ethiopians       Tatars      NaN      NaN      NaN
# 224588    Hardest   904.0     Indians  Lithuanians      NaN      NaN      NaN
# 224595    Hardest  1066.0     Berbers   Ethiopians      NaN      NaN      NaN
#
#         p2_ypos  winner
# 7           NaN       1
# 14          NaN       1
# 16          NaN       1
# 28          NaN       0
# 111         NaN       0
# ...         ...     ...
# 224537      NaN       0
# 224548      NaN       0
# 224549      NaN       1
# 224588      NaN       1
# 224595      NaN       0
#
# [10596 rows x 14 columns]

# %%
print("p1: ", df.p1_xpos.mean(), df.p1_ypos.mean())
print("p2: ", df.p2_xpos.mean(), df.p2_ypos.mean())
# Out:
# p1:  59.16979201226151 59.402606505516275
# p2:  59.41769040620926 59.40581674088681

# %%
print("p1: ", df.p1_xpos.mode().values[0], df.p1_ypos.mode().values[0])
print("p2: ", df.p2_xpos.mode().values[0], df.p2_ypos.mode().values[0])
# Out:
# p1:  20.0 20.0
# p2:  20.0 20.0

# %%
print("p1: ", df.p1_xpos.median(), df.p1_ypos.median())
print("p2: ", df.p2_xpos.median(), df.p2_ypos.median())
# Out:
# p1:  59.0 60.0
# p2:  59.0 60.0

# %%
len(df)
# Out:
# 224599

# %%
df_clean = df.dropna()

# %%
len(df_clean)
# Out:
# 214003

# %%
columns = []
unique_values_count = []
for col in df_clean.columns:
    if col != 'match_id':
        columns.append(col)
        unique_values_count.append(df_clean[col].nunique())

fig, ax = plt.subplots()
ax.bar(columns, unique_values_count)
ax.set_xticklabels(columns, rotation=45, ha='right')
ax.set_xlabel("columns")
ax.set_ylabel("nunique")
ax.set_title("unique values count")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/km/dql4gckx6ps4lrl0mdrhnsbh0000gn/T/ipykernel_32872/2861362802.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(columns, rotation=45, ha='right')

# %%
sns.countplot(data=df_clean, x='map')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=df_clean, x='p1_civ')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=df_clean, x='p2_civ')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=df_clean, x='winner')
plt.xticks(rotation=90)
plt.show()

# %%
numerical_features = list(df_clean.dtypes[df_clean.dtypes != 'object'].keys())
numerical_features = [feat for feat in numerical_features if feat not in ['match_id'] ]
numerical_features
# Out:
# ['duration', 'elo', 'p1_xpos', 'p2_xpos', 'p1_ypos', 'p2_ypos', 'winner']

# %%
correlations = {k: [] for k in numerical_features }

for col in numerical_features:
    for col2 in numerical_features:
        correlations[col].append(df[col].corr(df[col2])) 

correlation_matrix = pd.DataFrame(correlations)
correlation_matrix.index = numerical_features

correlation_matrix
# Out:
#           duration       elo   p1_xpos   p2_xpos   p1_ypos   p2_ypos    winner
# duration  1.000000 -0.116326  0.006255 -0.005667  0.001225 -0.000818 -0.007744
# elo      -0.116326  1.000000 -0.001879  0.000809  0.000464 -0.000823  0.001986
# p1_xpos   0.006255 -0.001879  1.000000 -0.814086 -0.000781 -0.000235  0.003774
# p2_xpos  -0.005667  0.000809 -0.814086  1.000000 -0.001048 -0.002833 -0.005998
# p1_ypos   0.001225  0.000464 -0.000781 -0.001048  1.000000 -0.813056 -0.000491
# p2_ypos  -0.000818 -0.000823 -0.000235 -0.002833 -0.813056  1.000000  0.000534
# winner   -0.007744  0.001986  0.003774 -0.005998 -0.000491  0.000534  1.000000

# %%
categorical_features = list(df_clean.dtypes[df_clean.dtypes == 'object'].keys())
categorical_features = [feat for feat in categorical_features if feat not in ['map_size', 'dataset', 'difficulty']]
categorical_features
# Out:
# ['map', 'p1_civ', 'p2_civ']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mutual_info_score, roc_auc_score
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression

# %%
mi = df_clean[categorical_features].apply(lambda s: mutual_info_score(s, df_clean.winner))
mi.sort_values(ascending = False)
# Out:
# p1_civ    0.001042
# p2_civ    0.000975
# map       0.000080
# dtype: float64

# %%
df_full_train, df_test = train_test_split(df_clean, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=42)
y_full_train = df_full_train.winner
y_test = df_test.winner
y_train = df_train.winner
y_val = df_val.winner

df_full_train = df_full_train.drop(columns=['winner'])
df_train = df_train.drop(columns=['winner'])
df_val = df_val.drop(columns=['winner'])

# %%
numerical_features = list(df_train.dtypes[df_train.dtypes != 'object'].keys())
numerical_features = [feat for feat in numerical_features if feat not in ['match_id'] ]
categorical_features = list(df_clean.dtypes[df_clean.dtypes == 'object'].keys())
categorical_features = [feat for feat in categorical_features if feat not in ['map_size', 'dataset', 'difficulty']]

# %%
dicts = df_train[categorical_features + numerical_features].to_dict(orient='records')
dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(dicts)
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

# %%
dicts = df_val[categorical_features + numerical_features].to_dict(orient='records')
X_val = dv.transform(dicts)
y_pred = model.predict(X_val)
round((y_val == y_pred).mean(), 2)
# Out:
# np.float64(0.52)

# %%
roc_auc_score(y_val, y_pred)
# Out:
# 0.5186112578102312

# %%
dicts = df_train[categorical_features + numerical_features].to_dict(orient='records')
dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(dicts)
model = LogisticRegression(solver='newton-cholesky', C=1.0, max_iter=1000, random_state=42)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='newton-cholesky')

# %%
dicts = df_val[categorical_features + numerical_features].to_dict(orient='records')
X_val = dv.transform(dicts)
y_pred = model.predict(X_val)
round((y_val == y_pred).mean(), 2)
# Out:
# np.float64(0.52)

# %%
roc_auc_score(y_val, y_pred)
# Out:
# 0.5186112578102312

# %%
dicts = df_train[categorical_features + numerical_features].to_dict(orient='records')
X_train = dv.fit_transform(dicts)
model.fit(X_train, y_train)

dicts = df_val[categorical_features + numerical_features].to_dict(orient='records')
X_val = dv.transform(dicts)
y_pred = model.predict(X_val)
original_accuracy = (y_val == y_pred).mean()
print('Original:', original_accuracy)

for f in categorical_features + numerical_features:
    smaller_features = [feature for feature in categorical_features + numerical_features if feature != f]
    dicts_smaller = df_train[smaller_features].to_dict(orient='records')
    X_train = dv.fit_transform(dicts_smaller)
    model.fit(X_train, y_train)

    dicts = df_val[smaller_features].to_dict(orient='records')
    X_val = dv.transform(dicts)
    y_pred = model.predict(X_val)
    print(f'Without {f} difference:', original_accuracy - (y_val == y_pred).mean())
# Out:
# Original: 0.5205485853134273
# Without map difference: -0.0008177379033199594
# Without p1_civ difference: 0.005981168664283554
# Without p2_civ difference: 0.00560734562276588
# Without duration difference: 0.0014252003457863038
# Without elo difference: -9.345576037944614e-05
# Without p1_xpos difference: -0.00035045910142283976
# Without p2_xpos difference: 2.3363940094944802e-05
# Without p1_ypos difference: 0.00025700334104350464
# Without p2_ypos difference: -0.0001401836405691137

# %%
numerical_features = list(df_train.dtypes[df_train.dtypes != 'object'].keys())
numerical_features = [feat for feat in numerical_features if feat not in ['match_id', 'elo', 'p1_xpos', 'p2_xpos', 'p1_ypos', 'p2_yps'] ]
categorical_features = list(df_clean.dtypes[df_clean.dtypes == 'object'].keys())
categorical_features = [feat for feat in categorical_features if feat not in ['map_size', 'dataset', 'difficulty', 'map']]
dicts = df_train[categorical_features + numerical_features].to_dict(orient='records')
dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(dicts)
model = LogisticRegression(solver='newton-cholesky', C=1.0, max_iter=1000, random_state=42)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='newton-cholesky')

# %%
dicts = df_val[categorical_features + numerical_features].to_dict(orient='records')
X_val = dv.transform(dicts)
y_pred = model.predict(X_val)
round((y_val == y_pred).mean(), 2)
# Out:
# np.float64(0.52)

# %%
for C in [0.01, 0.1, 1, 10, 100]:
    dicts = df_train[categorical_features + numerical_features].to_dict(orient='records')
    X_train = dv.fit_transform(dicts)
    model = LogisticRegression(solver='newton-cholesky', C=C, random_state=42)
    model.fit(X_train, y_train)

    dicts = df_val[categorical_features + numerical_features].to_dict(orient='records')
    X_val = dv.transform(dicts)
    y_pred = model.predict(X_val)
    accuracy = round((y_val == y_pred).mean(), 3)
    score = roc_auc_score(y_val, y_pred)
    print(f"{C}:", accuracy, score)
# Out:
# 0.01: 0.521 0.518751390808487
# 0.1: 0.521 0.5190855080796896
# 1: 0.521 0.5190524835785499
# 10: 0.521 0.5192178747181773
# 100: 0.521 0.519194866112959

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
dicts = df_train[categorical_features + numerical_features].to_dict(orient='records')
dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(dicts)

dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
dicts = df_val[categorical_features + numerical_features].to_dict(orient='records')
X_val = dv.transform(dicts)
y_pred = dt.predict(X_val)
round((y_val == y_pred).mean(), 2)
# Out:
# np.float64(0.51)

# %%
roc_auc_score(y_val, y_pred)
# Out:
# 0.5100044571392055

# %%
for d in [1, 2, 3, 4, 5, 6, 10, 15, 20, None]:
    dt = DecisionTreeClassifier(max_depth=d)
    dt.fit(X_train, y_train)

    y_pred = dt.predict(X_val)
    auc = roc_auc_score(y_val, y_pred)

    y_pred = dt.predict(X_train)
    auc_train = roc_auc_score(y_train, y_pred)

    print('%4s -> %.3f -> %.3f' % (d, auc, auc_train))
# Out:
#    1 -> 0.500 -> 0.500
#    2 -> 0.507 -> 0.508
#    3 -> 0.509 -> 0.511
#    4 -> 0.515 -> 0.519
#    5 -> 0.518 -> 0.522
#    6 -> 0.517 -> 0.524
#   10 -> 0.520 -> 0.535
#   15 -> 0.520 -> 0.560
#   20 -> 0.520 -> 0.595
# None -> 0.511 -> 1.000

# %%
scores = []

for d in [10, 15, 20]:
    for s in [1, 2, 5, 10, 15, 20, 100, 200, 500]:
        dt = DecisionTreeClassifier(max_depth=d, min_samples_leaf=s)
        dt.fit(X_train, y_train)

        y_pred = dt.predict(X_val)
        auc = roc_auc_score(y_val, y_pred)

        scores.append([d, s, auc])

df_scores = pd.DataFrame(scores, columns=['max_depth', 'min_samples_leaf', 'auc'])
df_scores.sort_values(by='auc', ascending=False)
# Out:
#     max_depth  min_samples_leaf       auc
# 17         15               500  0.522613
# 14         15                20  0.521159
# 26         20               500  0.520999
# 8          10               500  0.520979
# 12         15                10  0.520411
# 20         20                 5  0.520302
# 13         15                15  0.520275
# 0          10                 1  0.520257
# 1          10                 2  0.520236
# 9          15                 1  0.520123
# 21         20                10  0.520008
# 2          10                 5  0.519967
# 10         15                 2  0.519959
# 5          10                20  0.519858
# 22         20                15  0.519858
# 19         20                 2  0.519833
# 11         15                 5  0.519830
# 16         15               200  0.519758
# 18         20                 1  0.519637
# 4          10                15  0.519339
# 3          10                10  0.519197
# 25         20               200  0.518985
# 23         20                20  0.518598
# 6          10               100  0.517913
# 7          10               200  0.517571
# 15         15               100  0.517550
# 24         20               100  0.517356

# %%
rf = RandomForestClassifier(n_estimators=10, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=42)

# %%
y_pred = rf.predict(X_val)
roc_auc_score(y_val, y_pred)
# Out:
# 0.5136421340043446

# %%
scores = []

for n in range(10, 201, 10):
    rf = RandomForestClassifier(n_estimators=n, random_state=42)
    rf.fit(X_train, y_train)

    y_pred = rf.predict(X_val)
    auc = roc_auc_score(y_val, y_pred)
    scores.append((n, auc))

df_scores = pd.DataFrame(scores, columns=["n_estimators", "auc"])
df_scores
# Out:
#     n_estimators       auc
# 0             10  0.513642
# 1             20  0.514914
# 2             30  0.516396
# 3             40  0.517170
# 4             50  0.517096
# 5             60  0.516692
# 6             70  0.518273
# 7             80  0.516994
# 8             90  0.517514
# 9            100  0.516841
# 10           110  0.516731
# 11           120  0.517053
# 12           130  0.515701
# 13           140  0.516336
# 14           150  0.516669
# 15           160  0.516685
# 16           170  0.516543
# 17           180  0.516361
# 18           190  0.516451
# 19           200  0.516746

# %%
plt.plot(df_scores.n_estimators, df_scores.auc)

# %%
scores = []

for d in [5, 10, 15, 20]:
    for n in range(10, 201, 10):
        rf = RandomForestClassifier(n_estimators=n, max_depth=d, random_state=42)
        rf.fit(X_train, y_train)

        y_pred = rf.predict(X_val)
        auc = roc_auc_score(y_val, y_pred)
        scores.append((d, n, auc))

# %%
df_scores = pd.DataFrame(scores, columns=["max_depth", "n_estimators", "auc"])
df_scores.head()
# Out:
#    max_depth  n_estimators       auc
# 0          5            10  0.509725
# 1          5            20  0.510097
# 2          5            30  0.513353
# 3          5            40  0.512298
# 4          5            50  0.513343

# %%
for d in [5, 10, 15, 20]:
    df_subset = df_scores[df_scores.max_depth == d]
    plt.plot(df_subset.n_estimators, df_subset.auc, label='max_depth=%d'% d)
plt.legend()

# %%
df_scores[df_scores.max_depth == 20]
# Out:
#     max_depth  n_estimators       auc
# 60         20            10  0.517554
# 61         20            20  0.520790
# 62         20            30  0.522545
# 63         20            40  0.522698
# 64         20            50  0.523939
# 65         20            60  0.522200
# 66         20            70  0.522706
# 67         20            80  0.523271
# 68         20            90  0.522701
# 69         20           100  0.522390
# 70         20           110  0.523691
# 71         20           120  0.523580
# 72         20           130  0.524204
# 73         20           140  0.524982
# 74         20           150  0.525025
# 75         20           160  0.524420
# 76         20           170  0.524073
# 77         20           180  0.524415
# 78         20           190  0.525018
# 79         20           200  0.524693

# %%
max_depth = 20

# %%
from tqdm import tqdm

# %%
scores = []

for s in tqdm([1, 2, 5, 10, 15, 20, 100, 200, 500]):
    for n in range(10, 201, 10):
        rf = RandomForestClassifier(n_estimators=n, max_depth=max_depth, min_samples_leaf=s, random_state=42)
        rf.fit(X_train, y_train)

        y_pred = rf.predict(X_val)
        auc = roc_auc_score(y_val, y_pred)
        scores.append((s, n, auc))
# Out:
# 100%|██████████| 9/9 [21:31<00:00, 143.54s/it]

# %%
df_scores = pd.DataFrame(scores, columns=["min_samples_leaf", "n_estimators", "auc"])
df_scores.head()
# Out:
#    min_samples_leaf  n_estimators       auc
# 0                 1            10  0.517554
# 1                 1            20  0.520790
# 2                 1            30  0.522545
# 3                 1            40  0.522698
# 4                 1            50  0.523939

# %%
for s in [1, 2, 5, 10, 15, 20, 100, 200, 500]:
    df_subset = df_scores[df_scores.min_samples_leaf == s]
    plt.plot(df_subset.n_estimators, df_subset.auc, label='min_samples_leaf=%d'% s)
plt.legend()

# %%
df_scores[df_scores.min_samples_leaf == 5]
# Out:
#     min_samples_leaf  n_estimators       auc
# 40                 5            10  0.524214
# 41                 5            20  0.523795
# 42                 5            30  0.527391
# 43                 5            40  0.528174
# 44                 5            50  0.526631
# 45                 5            60  0.526786
# 46                 5            70  0.527431
# 47                 5            80  0.528091
# 48                 5            90  0.527247
# 49                 5           100  0.526321
# 50                 5           110  0.526844
# 51                 5           120  0.527221
# 52                 5           130  0.526646
# 53                 5           140  0.526536
# 54                 5           150  0.526901
# 55                 5           160  0.527122
# 56                 5           170  0.528035
# 57                 5           180  0.526846
# 58                 5           190  0.527513
# 59                 5           200  0.526596
